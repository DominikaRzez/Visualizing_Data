# %%
 # Dependencies
import requests
import json
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
import seaborn as sns
import scipy.stats as st
import os
import gmaps

# %%
# URL for GET requests to retrieve data

base_url = "https://data.police.uk/api/stops-street?"

# %%
# parameters for the data request

params = {"lat" : 51.5072,
          "lng" : -0.1276,
          "date" : "2021-01"}

# %%
# Pretty Print the output of the JSON
january = requests.get(base_url, params=params).json()
january
# Out:
# [{'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-03T14:56:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Evidence of offences under the Act'},
#  {'age_range': '18-24',
#   'outcome': 'Caution (simple or conditional)',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-03T21:14:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-caution',
#    'name': 'Caution (simple or conditional)'},
#   'location': {'latitude': '52.488400',
#    'street': {'id': 1488812, 'name': 'Duddeston (Station)'},
#    'longitude': '-1.871480'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-05T14:33:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.481994',
#    'street': {'id': 1489621, 'name': 'Bull Street (Tram Stop)'},
#    'longitude': '-1.896485'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-07T16:18:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-07T19:22:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.478321',
#    'street': {'id': 1490260, 'name': 'Birmingham New Street (Station)'},
#    'longitude': '-1.898042'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Anything to threaten or harm anyone'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Any other ethnic group',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-07T14:18:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-09T19:17:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-11T05:58:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-11T10:22:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Black Caribbean',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-19T15:34:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-20T19:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-20T19:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-21T22:43:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-21T00:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-21T00:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-23T00:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-25T16:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.482993',
#    'street': {'id': 1489594, 'name': 'Birmingham Snow Hill (Station)'},
#    'longitude': '-1.897911'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-28T21:26:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-01T14:38:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.480049',
#    'street': {'id': 1255987, 'name': 'On or near New Meeting Street'},
#    'longitude': '-1.893280'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-01T14:40:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.480049',
#    'street': {'id': 1255987, 'name': 'On or near New Meeting Street'},
#    'longitude': '-1.893280'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-01T15:19:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.499869',
#    'street': {'id': 1259940, 'name': 'On or near Aldersea Drive'},
#    'longitude': '-1.889608'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-01T15:22:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.499869',
#    'street': {'id': 1259940, 'name': 'On or near Aldersea Drive'},
#    'longitude': '-1.889608'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-01T17:04:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.479366',
#    'street': {'id': 1256014, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.893782'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-01T17:04:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.479366',
#    'street': {'id': 1256014, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.893782'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-02T00:53:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.489254',
#    'street': {'id': 1258668, 'name': 'On or near Bagot Street'},
#    'longitude': '-1.892227'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-02T00:54:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.489254',
#    'street': {'id': 1258668, 'name': 'On or near Bagot Street'},
#    'longitude': '-1.892227'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-02T00:55:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.488512',
#    'street': {'id': 1258698, 'name': 'On or near Parking Area'},
#    'longitude': '-1.887531'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-02T00:55:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.489254',
#    'street': {'id': 1258668, 'name': 'On or near Bagot Street'},
#    'longitude': '-1.892227'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'Community resolution',
#   'involved_person': False,
#   'self_defined_ethnicity': None,
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-02T03:53:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.484115',
#    'street': {'id': 1255985, 'name': 'On or near Printing House Street'},
#    'longitude': '-1.896068'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-02T14:35:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.499769',
#    'street': {'id': 1259890, 'name': 'On or near Rosefield Croft'},
#    'longitude': '-1.888342'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': None,
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-02T20:09:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.493367',
#    'street': {'id': 1258734, 'name': 'On or near Attenborough Close'},
#    'longitude': '-1.897784'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-02T21:53:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '52.487398',
#    'street': {'id': 1258740, 'name': 'On or near Finstall Close'},
#    'longitude': '-1.878536'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T12:44:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.481417',
#    'street': {'id': 1255974, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.894661'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Black Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T12:39:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.481417',
#    'street': {'id': 1255974, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.894661'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T12:41:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.481417',
#    'street': {'id': 1255974, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.894661'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T13:55:00+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.476614',
#    'street': {'id': 1255950, 'name': 'On or near Nightclub'},
#    'longitude': '-1.892331'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T18:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.498961',
#    'street': {'id': 1259959, 'name': 'On or near Clifford Street'},
#    'longitude': '-1.900541'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T20:21:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.482715',
#    'street': {'id': 1256016, 'name': 'On or near Supermarket'},
#    'longitude': '-1.898516'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T21:14:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.475009',
#    'street': {'id': 1255833, 'name': 'On or near Adderley Street'},
#    'longitude': '-1.878319'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Bangladeshi',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-03T21:19:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.475009',
#    'street': {'id': 1255833, 'name': 'On or near Adderley Street'},
#    'longitude': '-1.878319'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-04T00:05:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.481044',
#    'street': {'id': 1255845, 'name': 'On or near Garrison Street'},
#    'longitude': '-1.872060'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-04T14:03:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.475540',
#    'street': {'id': 1255957,
#     'name': 'On or near Conference/Exhibition Centre'},
#    'longitude': '-1.897605'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-04T14:03:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.474235',
#    'street': {'id': 1255919, 'name': 'On or near Parking Area'},
#    'longitude': '-1.895841'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-04T14:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.475755',
#    'street': {'id': 1255955, 'name': 'On or near Nightclub'},
#    'longitude': '-1.896367'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-04T18:47:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.474235',
#    'street': {'id': 1255919, 'name': 'On or near Parking Area'},
#    'longitude': '-1.895841'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-04T20:42:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.478130',
#    'street': {'id': 1255960, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.898659'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-04T20:44:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.477535',
#    'street': {'id': 1255905, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.896319'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-05T17:57:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.484799',
#    'street': {'id': 1256069, 'name': 'On or near Brook Street'},
#    'longitude': '-1.907508'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-01-05T20:49:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '52.476510',
#    'street': {'id': 1255904, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.896719'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-06T15:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '52.478130',
#    'street': {'id': 1255960, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.898659'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-06T16:24:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.497144',
#    'street': {'id': 1258681, 'name': 'On or near Porchester Street'},
#    'longitude': '-1.898335'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-06T15:43:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.497144',
#    'street': {'id': 1258681, 'name': 'On or near Porchester Street'},
#    'longitude': '-1.898335'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-06T15:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.497144',
#    'street': {'id': 1258681, 'name': 'On or near Porchester Street'},
#    'longitude': '-1.898335'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': None,
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-06T15:46:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.497144',
#    'street': {'id': 1258681, 'name': 'On or near Porchester Street'},
#    'longitude': '-1.898335'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-06T18:37:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.497144',
#    'street': {'id': 1258681, 'name': 'On or near Porchester Street'},
#    'longitude': '-1.898335'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '25-34',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-07T16:32:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '52.486823',
#    'street': {'id': 1258632, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.898815'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-07T19:52:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.494727',
#    'street': {'id': 1258659, 'name': 'On or near Frankfort Street'},
#    'longitude': '-1.899843'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': False,
#   'self_defined_ethnicity': None,
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-07T21:29:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.474235',
#    'street': {'id': 1255919, 'name': 'On or near Parking Area'},
#    'longitude': '-1.895841'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-08T17:32:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.494892',
#    'street': {'id': 1258639, 'name': 'On or near St Stephens Street'},
#    'longitude': '-1.894172'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-08T17:13:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.498139',
#    'street': {'id': 1258675, 'name': 'On or near Parking Area'},
#    'longitude': '-1.895269'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-08T17:37:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.494491',
#    'street': {'id': 1258661, 'name': 'On or near Chilwell Croft'},
#    'longitude': '-1.897841'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-08T17:13:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.498139',
#    'street': {'id': 1258675, 'name': 'On or near Parking Area'},
#    'longitude': '-1.895269'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
# ...
#    'longitude': '-1.892918'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Bangladeshi',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-23T22:28:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.482404',
#    'street': {'id': 1255969, 'name': 'On or near Parking Area'},
#    'longitude': '-1.892847'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-23T22:48:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.482404',
#    'street': {'id': 1255969, 'name': 'On or near Parking Area'},
#    'longitude': '-1.892847'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': False,
#   'self_defined_ethnicity': None,
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-25T17:43:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.484236',
#    'street': {'id': 1255892, 'name': 'On or near Pitt Street'},
#    'longitude': '-1.881534'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-25T18:12:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.479224',
#    'street': {'id': 1255959, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.895697'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-26T00:46:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.478997',
#    'street': {'id': 1255909, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.893194'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-27T16:27:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477828',
#    'street': {'id': 1243748, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.892903'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-27T16:27:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477828',
#    'street': {'id': 1243748, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.892903'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-28T19:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.497841',
#    'street': {'id': 1258603, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.904064'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': '',
#   'involved_person': False,
#   'self_defined_ethnicity': None,
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-29T20:20:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.476951',
#    'street': {'id': 1255948, 'name': 'On or near Bus/Coach Station'},
#    'longitude': '-1.897425'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-30T12:37:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.473434',
#    'street': {'id': 1256027, 'name': 'On or near Claybrook Street'},
#    'longitude': '-1.895018'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': None,
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-30T18:25:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.478997',
#    'street': {'id': 1255909, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.893194'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': None,
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-30T18:25:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.478997',
#    'street': {'id': 1255909, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.893194'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Bangladeshi',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-30T20:41:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.479694',
#    'street': {'id': 1255843, 'name': 'On or near Hoff Beck Court'},
#    'longitude': '-1.870650'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-31T12:42:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.479224',
#    'street': {'id': 1255959, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.895697'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-31T12:44:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.478755',
#    'street': {'id': 1255962, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.894167'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Black Caribbean',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-31T14:17:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.480049',
#    'street': {'id': 1255987, 'name': 'On or near New Meeting Street'},
#    'longitude': '-1.893280'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-31T14:22:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.480049',
#    'street': {'id': 1255987, 'name': 'On or near New Meeting Street'},
#    'longitude': '-1.893280'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-31T14:32:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.480049',
#    'street': {'id': 1255987, 'name': 'On or near New Meeting Street'},
#    'longitude': '-1.893280'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Black Caribbean',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-31T16:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.475237',
#    'street': {'id': 1255911, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.900241'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-01-31T16:14:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.475237',
#    'street': {'id': 1255911, 'name': 'On or near Pedestrian Subway'},
#    'longitude': '-1.900241'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-07T15:23:21+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.478083',
#    'street': {'id': 1255921, 'name': 'On or near Worcester Street'},
#    'longitude': '-1.895758'},
#   'operation': True,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'}]

# %%
# Save as Pandas Data Frame
london_jan_df = pd.DataFrame.from_dict(january)
london_jan_df
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 142     10-17                                              True
# 143     18-24     A no further action disposal             True
# 144     18-24     A no further action disposal             True
# 145      None     A no further action disposal             True
# 146     25-34     A no further action disposal             True
#
#                                 self_defined_ethnicity gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...   Male
# 1                      Asian/Asian British - Pakistani   Male
# 2    White - English/Welsh/Scottish/Northern Irish/...   Male
# 3    White - English/Welsh/Scottish/Northern Irish/...   Male
# 4    White - English/Welsh/Scottish/Northern Irish/...   Male
# ..                                                 ...    ...
# 142  Black/African/Caribbean/Black British - Caribbean   None
# 143                    Asian/Asian British - Pakistani   None
# 144  Mixed/Multiple ethnic groups - White and Black...   None
# 145  Black/African/Caribbean/Black British - Caribbean   None
# 146    Black/African/Caribbean/Black British - African   Male
#
#                                            legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3                Misuse of Drugs Act 1971 (section 23)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 142              Misuse of Drugs Act 1971 (section 23)
# 143              Misuse of Drugs Act 1971 (section 23)
# 144              Misuse of Drugs Act 1971 (section 23)
# 145              Misuse of Drugs Act 1971 (section 23)
# 146              Misuse of Drugs Act 1971 (section 23)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                 True  2021-01-03T14:56:00+00:00
# 1                                 True  2021-01-03T21:14:00+00:00
# 2                                False  2021-01-05T14:33:00+00:00
# 3                                False  2021-01-07T16:18:00+00:00
# 4                                False  2021-01-07T19:22:00+00:00
# ..                                 ...                        ...
# 142                               None  2021-01-31T14:22:00+00:00
# 143                               None  2021-01-31T14:32:00+00:00
# 144                               None  2021-01-31T16:10:00+00:00
# 145                               None  2021-01-31T16:14:00+00:00
# 146                               True  2021-01-07T15:23:21+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 142                               False
# 143                               False
# 144                               False
# 145                               False
# 146                                None
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1    {'id': 'bu-caution', 'name': 'Caution (simple ...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 142                             {'id': '', 'name': ''}
# 143  {'id': 'bu-no-further-action', 'name': 'A no f...
# 144  {'id': 'bu-no-further-action', 'name': 'A no f...
# 145  {'id': 'bu-no-further-action', 'name': 'A no f...
# 146  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                               location operation  \
# 0    {'latitude': '52.477800', 'street': {'id': 148...      None
# 1    {'latitude': '52.488400', 'street': {'id': 148...      None
# 2    {'latitude': '52.481994', 'street': {'id': 148...      None
# 3    {'latitude': '52.477800', 'street': {'id': 148...      None
# 4    {'latitude': '52.478321', 'street': {'id': 149...      None
# ..                                                 ...       ...
# 142  {'latitude': '52.480049', 'street': {'id': 125...      None
# 143  {'latitude': '52.480049', 'street': {'id': 125...      None
# 144  {'latitude': '52.475237', 'street': {'id': 125...      None
# 145  {'latitude': '52.475237', 'street': {'id': 125...      None
# 146  {'latitude': '52.478083', 'street': {'id': 125...      True
#
#     officer_defined_ethnicity           type operation_name  \
# 0                        None  Person search           None
# 1                       Asian  Person search           None
# 2                       White  Person search           None
# 3                       White  Person search           None
# 4                       White  Person search           None
# ..                        ...            ...            ...
# 142                      None  Person search           None
# 143                     Asian  Person search           None
# 144                     Other  Person search           None
# 145                      None  Person search           None
# 146                     Black  Person search           None
#
#                         object_of_search
# 0     Evidence of offences under the Act
# 1                       Controlled drugs
# 2                           Stolen goods
# 3                       Controlled drugs
# 4    Anything to threaten or harm anyone
# ..                                   ...
# 142                     Controlled drugs
# 143                     Controlled drugs
# 144                     Controlled drugs
# 145                     Controlled drugs
# 146                     Controlled drugs
#
# [147 rows x 16 columns]

# %%
# Repeat process for all the other months
params1 = params = {"lat" : 51.5072,
          "lng" : -0.1276,
          "date" : "2021-02"}

# %%
february = requests.get(base_url, params=params1).json()

# %%
london_feb_df = pd.DataFrame.from_dict(february)
london_feb_df
# Out:
#     age_range                       outcome  involved_person  \
# 0       18-24  A no further action disposal             True
# 1       10-17                        Arrest             True
# 2       10-17  A no further action disposal             True
# 3       10-17  A no further action disposal             True
# 4     over 34  A no further action disposal             True
# ..        ...                           ...              ...
# 685     10-17  A no further action disposal             True
# 686     18-24  A no further action disposal             True
# 687     18-24                        Arrest             True
# 688     25-34  A no further action disposal             True
# 689     25-34                        Arrest             True
#
#                                 self_defined_ethnicity  gender  \
# 0                      Other ethnic group - Not stated    Male
# 1                      Other ethnic group - Not stated  Female
# 2                      Other ethnic group - Not stated    Male
# 3    White - English/Welsh/Scottish/Northern Irish/...    Male
# 4      Black/African/Caribbean/Black British - African    Male
# ..                                                 ...     ...
# 685                 White - Any other White background    Male
# 686  White - English/Welsh/Scottish/Northern Irish/...    Male
# 687                    Other ethnic group - Not stated    Male
# 688                    Other ethnic group - Not stated    Male
# 689                 White - Any other White background    Male
#
#                                            legislation  \
# 0                Misuse of Drugs Act 1971 (section 23)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3                Misuse of Drugs Act 1971 (section 23)
# 4                Misuse of Drugs Act 1971 (section 23)
# ..                                                 ...
# 685  Police and Criminal Evidence Act 1984 (section 1)
# 686              Misuse of Drugs Act 1971 (section 23)
# 687  Police and Criminal Evidence Act 1984 (section 1)
# 688  Police and Criminal Evidence Act 1984 (section 1)
# 689  Police and Criminal Evidence Act 1984 (section 1)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                False  2021-02-27T13:45:00+00:00
# 1                                 True  2021-02-25T09:24:00+00:00
# 2                                 None  2021-02-17T01:33:00+00:00
# 3                                False  2021-02-06T17:15:00+00:00
# 4                                False  2021-02-08T10:22:00+00:00
# ..                                 ...                        ...
# 685                               None  2021-02-27T13:51:00+00:00
# 686                              False  2021-02-17T05:42:26+00:00
# 687                               True  2021-02-06T10:01:15+00:00
# 688                              False  2021-02-11T07:40:53+00:00
# 689                               True  2021-02-28T12:02:10+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                  None
# 3                                 False
# 4                                 False
# ..                                  ...
# 685                                None
# 686                               False
# 687                               False
# 688                               False
# 689                               False
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1                {'id': 'bu-arrest', 'name': 'Arrest'}
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 685  {'id': 'bu-no-further-action', 'name': 'A no f...
# 686  {'id': 'bu-no-further-action', 'name': 'A no f...
# 687              {'id': 'bu-arrest', 'name': 'Arrest'}
# 688  {'id': 'bu-no-further-action', 'name': 'A no f...
# 689              {'id': 'bu-arrest', 'name': 'Arrest'}
#
#                                               location operation  \
# 0    {'latitude': '51.503381', 'street': {'id': 149...      None
# 1    {'latitude': '51.503381', 'street': {'id': 149...      None
# 2    {'latitude': '51.499506', 'street': {'id': 953...     False
# 3    {'latitude': '51.503381', 'street': {'id': 149...      None
# 4    {'latitude': '51.507300', 'street': {'id': 148...      None
# ..                                                 ...       ...
# 685  {'latitude': '51.515111', 'street': {'id': 956...     False
# 686  {'latitude': '51.511749', 'street': {'id': 587...      None
# 687  {'latitude': '51.513581', 'street': {'id': 587...      None
# 688  {'latitude': '51.513928', 'street': {'id': 587...      None
# 689  {'latitude': '51.516738', 'street': {'id': 587...      None
#
#     officer_defined_ethnicity           type operation_name  \
# 0                       Black  Person search           None
# 1                       White  Person search           None
# 2                       White  Person search           None
# 3                       White  Person search           None
# 4                       Black  Person search           None
# ..                        ...            ...            ...
# 685                     White  Person search           None
# 686                     White  Person search           None
# 687                     White  Person search           None
# 688                     White  Person search           None
# 689                     White  Person search           None
#
#              object_of_search
# 0            Controlled drugs
# 1            Controlled drugs
# 2           Offensive weapons
# 3            Controlled drugs
# 4            Controlled drugs
# ..                        ...
# 685              Stolen goods
# 686          Controlled drugs
# 687  Article for use in theft
# 688  Article for use in theft
# 689  Article for use in theft
#
# [690 rows x 16 columns]

# %%
params2 = params = {"lat" : 51.5072,
          "lng" : -0.1276,
          "date" : "2021-03"}

# %%
march = requests.get(base_url, params=params2).json()

# %%
london_mar_df = pd.DataFrame.from_dict(march)
london_mar_df
# Out:
#     age_range                       outcome  involved_person  \
# 0       18-24                        Arrest             True
# 1       25-34  A no further action disposal             True
# 2       25-34  A no further action disposal             True
# 3       18-24                        Arrest             True
# 4       10-17  A no further action disposal             True
# ..        ...                           ...              ...
# 705   over 34          Community resolution             True
# 706     18-24  A no further action disposal             True
# 707   over 34          Community resolution             True
# 708     25-34  A no further action disposal             True
# 709     18-24          Community resolution             True
#
#                                 self_defined_ethnicity  gender  \
# 0                      Other ethnic group - Not stated    Male
# 1    White - English/Welsh/Scottish/Northern Irish/...    Male
# 2                   White - Any other White background    Male
# 3          Other ethnic group - Any other ethnic group    Male
# 4                   White - Any other White background    Male
# ..                                                 ...     ...
# 705  White - English/Welsh/Scottish/Northern Irish/...    Male
# 706                    Other ethnic group - Not stated    Male
# 707                  Asian/Asian British - Bangladeshi    Male
# 708  White - English/Welsh/Scottish/Northern Irish/...    Male
# 709                 White - Any other White background  Female
#
#                                            legislation  \
# 0                Misuse of Drugs Act 1971 (section 23)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3    Police and Criminal Evidence Act 1984 (section 1)
# 4                Misuse of Drugs Act 1971 (section 23)
# ..                                                 ...
# 705              Misuse of Drugs Act 1971 (section 23)
# 706              Misuse of Drugs Act 1971 (section 23)
# 707              Misuse of Drugs Act 1971 (section 23)
# 708  Police and Criminal Evidence Act 1984 (section 1)
# 709              Misuse of Drugs Act 1971 (section 23)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                False  2021-03-02T23:01:00+00:00
# 1                                False  2021-03-01T12:30:00+00:00
# 2                                False  2021-03-03T10:24:00+00:00
# 3                                False  2021-03-03T21:56:00+00:00
# 4                                False  2021-03-08T19:25:00+00:00
# ..                                 ...                        ...
# 705                               None  2021-03-27T11:40:00+00:00
# 706                               None  2021-03-27T13:30:00+00:00
# 707                               None  2021-03-20T20:35:00+00:00
# 708                               None  2021-03-29T19:25:00+00:00
# 709                               None  2021-03-20T23:11:00+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 705                                None
# 706                                None
# 707                                None
# 708                                None
# 709                                None
#
#                                         outcome_object  \
# 0                {'id': 'bu-arrest', 'name': 'Arrest'}
# 1    {'id': 'bu-no-further-action', 'name': 'A no f...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3                {'id': 'bu-arrest', 'name': 'Arrest'}
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 705  {'id': 'bu-community-resolution', 'name': 'Com...
# 706  {'id': 'bu-no-further-action', 'name': 'A no f...
# 707  {'id': 'bu-community-resolution', 'name': 'Com...
# 708  {'id': 'bu-no-further-action', 'name': 'A no f...
# 709  {'id': 'bu-community-resolution', 'name': 'Com...
#
#                                               location operation  \
# 0    {'latitude': '51.503381', 'street': {'id': 149...      None
# 1    {'latitude': '51.503381', 'street': {'id': 149...      None
# 2    {'latitude': '51.503381', 'street': {'id': 149...      None
# 3    {'latitude': '51.507300', 'street': {'id': 148...      None
# 4    {'latitude': '51.515685', 'street': {'id': 148...      None
# ..                                                 ...       ...
# 705  {'latitude': '51.497899', 'street': {'id': 953...     False
# 706  {'latitude': '51.503986', 'street': {'id': 953...     False
# 707  {'latitude': '51.518181', 'street': {'id': 956...     False
# 708  {'latitude': '51.503196', 'street': {'id': 953...     False
# 709  {'latitude': '51.503986', 'street': {'id': 953...     False
#
#     officer_defined_ethnicity           type operation_name  \
# 0                       Black  Person search           None
# 1                       White  Person search           None
# 2                       White  Person search           None
# 3                       Other  Person search           None
# 4                       White  Person search           None
# ..                        ...            ...            ...
# 705                     White  Person search           None
# 706                     White  Person search           None
# 707                     Asian  Person search           None
# 708                     White  Person search           None
# 709                     White  Person search           None
#
#              object_of_search
# 0            Controlled drugs
# 1            Controlled drugs
# 2                Stolen goods
# 3    Article for use in theft
# 4            Controlled drugs
# ..                        ...
# 705          Controlled drugs
# 706          Controlled drugs
# 707          Controlled drugs
# 708         Offensive weapons
# 709          Controlled drugs
#
# [710 rows x 16 columns]

# %%
params3 = params = {"lat" : 51.5072,
          "lng" : -0.1276,
          "date" : "2021-04"}

# %%
april = requests.get(base_url, params=params3).json()

# %%
london_apr_df = pd.DataFrame.from_dict(march)
london_apr_df
# Out:
#     age_range                       outcome  involved_person  \
# 0       18-24                        Arrest             True
# 1       25-34  A no further action disposal             True
# 2       25-34  A no further action disposal             True
# 3       18-24                        Arrest             True
# 4       10-17  A no further action disposal             True
# ..        ...                           ...              ...
# 705   over 34          Community resolution             True
# 706     18-24  A no further action disposal             True
# 707   over 34          Community resolution             True
# 708     25-34  A no further action disposal             True
# 709     18-24          Community resolution             True
#
#                                 self_defined_ethnicity  gender  \
# 0                      Other ethnic group - Not stated    Male
# 1    White - English/Welsh/Scottish/Northern Irish/...    Male
# 2                   White - Any other White background    Male
# 3          Other ethnic group - Any other ethnic group    Male
# 4                   White - Any other White background    Male
# ..                                                 ...     ...
# 705  White - English/Welsh/Scottish/Northern Irish/...    Male
# 706                    Other ethnic group - Not stated    Male
# 707                  Asian/Asian British - Bangladeshi    Male
# 708  White - English/Welsh/Scottish/Northern Irish/...    Male
# 709                 White - Any other White background  Female
#
#                                            legislation  \
# 0                Misuse of Drugs Act 1971 (section 23)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3    Police and Criminal Evidence Act 1984 (section 1)
# 4                Misuse of Drugs Act 1971 (section 23)
# ..                                                 ...
# 705              Misuse of Drugs Act 1971 (section 23)
# 706              Misuse of Drugs Act 1971 (section 23)
# 707              Misuse of Drugs Act 1971 (section 23)
# 708  Police and Criminal Evidence Act 1984 (section 1)
# 709              Misuse of Drugs Act 1971 (section 23)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                False  2021-03-02T23:01:00+00:00
# 1                                False  2021-03-01T12:30:00+00:00
# 2                                False  2021-03-03T10:24:00+00:00
# 3                                False  2021-03-03T21:56:00+00:00
# 4                                False  2021-03-08T19:25:00+00:00
# ..                                 ...                        ...
# 705                               None  2021-03-27T11:40:00+00:00
# 706                               None  2021-03-27T13:30:00+00:00
# 707                               None  2021-03-20T20:35:00+00:00
# 708                               None  2021-03-29T19:25:00+00:00
# 709                               None  2021-03-20T23:11:00+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 705                                None
# 706                                None
# 707                                None
# 708                                None
# 709                                None
#
#                                         outcome_object  \
# 0                {'id': 'bu-arrest', 'name': 'Arrest'}
# 1    {'id': 'bu-no-further-action', 'name': 'A no f...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3                {'id': 'bu-arrest', 'name': 'Arrest'}
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 705  {'id': 'bu-community-resolution', 'name': 'Com...
# 706  {'id': 'bu-no-further-action', 'name': 'A no f...
# 707  {'id': 'bu-community-resolution', 'name': 'Com...
# 708  {'id': 'bu-no-further-action', 'name': 'A no f...
# 709  {'id': 'bu-community-resolution', 'name': 'Com...
#
#                                               location operation  \
# 0    {'latitude': '51.503381', 'street': {'id': 149...      None
# 1    {'latitude': '51.503381', 'street': {'id': 149...      None
# 2    {'latitude': '51.503381', 'street': {'id': 149...      None
# 3    {'latitude': '51.507300', 'street': {'id': 148...      None
# 4    {'latitude': '51.515685', 'street': {'id': 148...      None
# ..                                                 ...       ...
# 705  {'latitude': '51.497899', 'street': {'id': 953...     False
# 706  {'latitude': '51.503986', 'street': {'id': 953...     False
# 707  {'latitude': '51.518181', 'street': {'id': 956...     False
# 708  {'latitude': '51.503196', 'street': {'id': 953...     False
# 709  {'latitude': '51.503986', 'street': {'id': 953...     False
#
#     officer_defined_ethnicity           type operation_name  \
# 0                       Black  Person search           None
# 1                       White  Person search           None
# 2                       White  Person search           None
# 3                       Other  Person search           None
# 4                       White  Person search           None
# ..                        ...            ...            ...
# 705                     White  Person search           None
# 706                     White  Person search           None
# 707                     Asian  Person search           None
# 708                     White  Person search           None
# 709                     White  Person search           None
#
#              object_of_search
# 0            Controlled drugs
# 1            Controlled drugs
# 2                Stolen goods
# 3    Article for use in theft
# 4            Controlled drugs
# ..                        ...
# 705          Controlled drugs
# 706          Controlled drugs
# 707          Controlled drugs
# 708         Offensive weapons
# 709          Controlled drugs
#
# [710 rows x 16 columns]

# %%
jan_feb = london_jan_df.append(london_feb_df)

# %%
jan_feb
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 685     10-17     A no further action disposal             True
# 686     18-24     A no further action disposal             True
# 687     18-24                           Arrest             True
# 688     25-34     A no further action disposal             True
# 689     25-34                           Arrest             True
#
#                                 self_defined_ethnicity gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...   Male
# 1                      Asian/Asian British - Pakistani   Male
# 2    White - English/Welsh/Scottish/Northern Irish/...   Male
# 3    White - English/Welsh/Scottish/Northern Irish/...   Male
# 4    White - English/Welsh/Scottish/Northern Irish/...   Male
# ..                                                 ...    ...
# 685                 White - Any other White background   Male
# 686  White - English/Welsh/Scottish/Northern Irish/...   Male
# 687                    Other ethnic group - Not stated   Male
# 688                    Other ethnic group - Not stated   Male
# 689                 White - Any other White background   Male
#
#                                            legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3                Misuse of Drugs Act 1971 (section 23)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 685  Police and Criminal Evidence Act 1984 (section 1)
# 686              Misuse of Drugs Act 1971 (section 23)
# 687  Police and Criminal Evidence Act 1984 (section 1)
# 688  Police and Criminal Evidence Act 1984 (section 1)
# 689  Police and Criminal Evidence Act 1984 (section 1)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                 True  2021-01-03T14:56:00+00:00
# 1                                 True  2021-01-03T21:14:00+00:00
# 2                                False  2021-01-05T14:33:00+00:00
# 3                                False  2021-01-07T16:18:00+00:00
# 4                                False  2021-01-07T19:22:00+00:00
# ..                                 ...                        ...
# 685                               None  2021-02-27T13:51:00+00:00
# 686                              False  2021-02-17T05:42:26+00:00
# 687                               True  2021-02-06T10:01:15+00:00
# 688                              False  2021-02-11T07:40:53+00:00
# 689                               True  2021-02-28T12:02:10+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 685                                None
# 686                               False
# 687                               False
# 688                               False
# 689                               False
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1    {'id': 'bu-caution', 'name': 'Caution (simple ...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 685  {'id': 'bu-no-further-action', 'name': 'A no f...
# 686  {'id': 'bu-no-further-action', 'name': 'A no f...
# 687              {'id': 'bu-arrest', 'name': 'Arrest'}
# 688  {'id': 'bu-no-further-action', 'name': 'A no f...
# 689              {'id': 'bu-arrest', 'name': 'Arrest'}
#
#                                               location operation  \
# 0    {'latitude': '52.477800', 'street': {'id': 148...      None
# 1    {'latitude': '52.488400', 'street': {'id': 148...      None
# 2    {'latitude': '52.481994', 'street': {'id': 148...      None
# 3    {'latitude': '52.477800', 'street': {'id': 148...      None
# 4    {'latitude': '52.478321', 'street': {'id': 149...      None
# ..                                                 ...       ...
# 685  {'latitude': '51.515111', 'street': {'id': 956...     False
# 686  {'latitude': '51.511749', 'street': {'id': 587...      None
# 687  {'latitude': '51.513581', 'street': {'id': 587...      None
# 688  {'latitude': '51.513928', 'street': {'id': 587...      None
# 689  {'latitude': '51.516738', 'street': {'id': 587...      None
#
#     officer_defined_ethnicity           type operation_name  \
# 0                        None  Person search           None
# 1                       Asian  Person search           None
# 2                       White  Person search           None
# 3                       White  Person search           None
# 4                       White  Person search           None
# ..                        ...            ...            ...
# 685                     White  Person search           None
# 686                     White  Person search           None
# 687                     White  Person search           None
# 688                     White  Person search           None
# 689                     White  Person search           None
#
#                         object_of_search
# 0     Evidence of offences under the Act
# 1                       Controlled drugs
# 2                           Stolen goods
# 3                       Controlled drugs
# 4    Anything to threaten or harm anyone
# ..                                   ...
# 685                         Stolen goods
# 686                     Controlled drugs
# 687             Article for use in theft
# 688             Article for use in theft
# 689             Article for use in theft
#
# [837 rows x 16 columns]

# %%
jan_mar = jan_feb.append(london_mar_df)
jan_mar
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 705   over 34             Community resolution             True
# 706     18-24     A no further action disposal             True
# 707   over 34             Community resolution             True
# 708     25-34     A no further action disposal             True
# 709     18-24             Community resolution             True
#
#                                 self_defined_ethnicity  gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...    Male
# 1                      Asian/Asian British - Pakistani    Male
# 2    White - English/Welsh/Scottish/Northern Irish/...    Male
# 3    White - English/Welsh/Scottish/Northern Irish/...    Male
# 4    White - English/Welsh/Scottish/Northern Irish/...    Male
# ..                                                 ...     ...
# 705  White - English/Welsh/Scottish/Northern Irish/...    Male
# 706                    Other ethnic group - Not stated    Male
# 707                  Asian/Asian British - Bangladeshi    Male
# 708  White - English/Welsh/Scottish/Northern Irish/...    Male
# 709                 White - Any other White background  Female
#
#                                            legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3                Misuse of Drugs Act 1971 (section 23)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 705              Misuse of Drugs Act 1971 (section 23)
# 706              Misuse of Drugs Act 1971 (section 23)
# 707              Misuse of Drugs Act 1971 (section 23)
# 708  Police and Criminal Evidence Act 1984 (section 1)
# 709              Misuse of Drugs Act 1971 (section 23)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                 True  2021-01-03T14:56:00+00:00
# 1                                 True  2021-01-03T21:14:00+00:00
# 2                                False  2021-01-05T14:33:00+00:00
# 3                                False  2021-01-07T16:18:00+00:00
# 4                                False  2021-01-07T19:22:00+00:00
# ..                                 ...                        ...
# 705                               None  2021-03-27T11:40:00+00:00
# 706                               None  2021-03-27T13:30:00+00:00
# 707                               None  2021-03-20T20:35:00+00:00
# 708                               None  2021-03-29T19:25:00+00:00
# 709                               None  2021-03-20T23:11:00+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 705                                None
# 706                                None
# 707                                None
# 708                                None
# 709                                None
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1    {'id': 'bu-caution', 'name': 'Caution (simple ...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 705  {'id': 'bu-community-resolution', 'name': 'Com...
# 706  {'id': 'bu-no-further-action', 'name': 'A no f...
# 707  {'id': 'bu-community-resolution', 'name': 'Com...
# 708  {'id': 'bu-no-further-action', 'name': 'A no f...
# 709  {'id': 'bu-community-resolution', 'name': 'Com...
#
#                                               location operation  \
# 0    {'latitude': '52.477800', 'street': {'id': 148...      None
# 1    {'latitude': '52.488400', 'street': {'id': 148...      None
# 2    {'latitude': '52.481994', 'street': {'id': 148...      None
# 3    {'latitude': '52.477800', 'street': {'id': 148...      None
# 4    {'latitude': '52.478321', 'street': {'id': 149...      None
# ..                                                 ...       ...
# 705  {'latitude': '51.497899', 'street': {'id': 953...     False
# 706  {'latitude': '51.503986', 'street': {'id': 953...     False
# 707  {'latitude': '51.518181', 'street': {'id': 956...     False
# 708  {'latitude': '51.503196', 'street': {'id': 953...     False
# 709  {'latitude': '51.503986', 'street': {'id': 953...     False
#
#     officer_defined_ethnicity           type operation_name  \
# 0                        None  Person search           None
# 1                       Asian  Person search           None
# 2                       White  Person search           None
# 3                       White  Person search           None
# 4                       White  Person search           None
# ..                        ...            ...            ...
# 705                     White  Person search           None
# 706                     White  Person search           None
# 707                     Asian  Person search           None
# 708                     White  Person search           None
# 709                     White  Person search           None
#
#                         object_of_search
# 0     Evidence of offences under the Act
# 1                       Controlled drugs
# 2                           Stolen goods
# 3                       Controlled drugs
# 4    Anything to threaten or harm anyone
# ..                                   ...
# 705                     Controlled drugs
# 706                     Controlled drugs
# 707                     Controlled drugs
# 708                    Offensive weapons
# 709                     Controlled drugs
#
# [1547 rows x 16 columns]

# %%
jan_apr = jan_mar.append(london_apr_df)
jan_apr
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 705   over 34             Community resolution             True
# 706     18-24     A no further action disposal             True
# 707   over 34             Community resolution             True
# 708     25-34     A no further action disposal             True
# 709     18-24             Community resolution             True
#
#                                 self_defined_ethnicity  gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...    Male
# 1                      Asian/Asian British - Pakistani    Male
# 2    White - English/Welsh/Scottish/Northern Irish/...    Male
# 3    White - English/Welsh/Scottish/Northern Irish/...    Male
# 4    White - English/Welsh/Scottish/Northern Irish/...    Male
# ..                                                 ...     ...
# 705  White - English/Welsh/Scottish/Northern Irish/...    Male
# 706                    Other ethnic group - Not stated    Male
# 707                  Asian/Asian British - Bangladeshi    Male
# 708  White - English/Welsh/Scottish/Northern Irish/...    Male
# 709                 White - Any other White background  Female
#
#                                            legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3                Misuse of Drugs Act 1971 (section 23)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 705              Misuse of Drugs Act 1971 (section 23)
# 706              Misuse of Drugs Act 1971 (section 23)
# 707              Misuse of Drugs Act 1971 (section 23)
# 708  Police and Criminal Evidence Act 1984 (section 1)
# 709              Misuse of Drugs Act 1971 (section 23)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                 True  2021-01-03T14:56:00+00:00
# 1                                 True  2021-01-03T21:14:00+00:00
# 2                                False  2021-01-05T14:33:00+00:00
# 3                                False  2021-01-07T16:18:00+00:00
# 4                                False  2021-01-07T19:22:00+00:00
# ..                                 ...                        ...
# 705                               None  2021-03-27T11:40:00+00:00
# 706                               None  2021-03-27T13:30:00+00:00
# 707                               None  2021-03-20T20:35:00+00:00
# 708                               None  2021-03-29T19:25:00+00:00
# 709                               None  2021-03-20T23:11:00+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 705                                None
# 706                                None
# 707                                None
# 708                                None
# 709                                None
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1    {'id': 'bu-caution', 'name': 'Caution (simple ...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 705  {'id': 'bu-community-resolution', 'name': 'Com...
# 706  {'id': 'bu-no-further-action', 'name': 'A no f...
# 707  {'id': 'bu-community-resolution', 'name': 'Com...
# 708  {'id': 'bu-no-further-action', 'name': 'A no f...
# 709  {'id': 'bu-community-resolution', 'name': 'Com...
#
#                                               location operation  \
# 0    {'latitude': '52.477800', 'street': {'id': 148...      None
# 1    {'latitude': '52.488400', 'street': {'id': 148...      None
# 2    {'latitude': '52.481994', 'street': {'id': 148...      None
# 3    {'latitude': '52.477800', 'street': {'id': 148...      None
# 4    {'latitude': '52.478321', 'street': {'id': 149...      None
# ..                                                 ...       ...
# 705  {'latitude': '51.497899', 'street': {'id': 953...     False
# 706  {'latitude': '51.503986', 'street': {'id': 953...     False
# 707  {'latitude': '51.518181', 'street': {'id': 956...     False
# 708  {'latitude': '51.503196', 'street': {'id': 953...     False
# 709  {'latitude': '51.503986', 'street': {'id': 953...     False
#
#     officer_defined_ethnicity           type operation_name  \
# 0                        None  Person search           None
# 1                       Asian  Person search           None
# 2                       White  Person search           None
# 3                       White  Person search           None
# 4                       White  Person search           None
# ..                        ...            ...            ...
# 705                     White  Person search           None
# 706                     White  Person search           None
# 707                     Asian  Person search           None
# 708                     White  Person search           None
# 709                     White  Person search           None
#
#                         object_of_search
# 0     Evidence of offences under the Act
# 1                       Controlled drugs
# 2                           Stolen goods
# 3                       Controlled drugs
# 4    Anything to threaten or harm anyone
# ..                                   ...
# 705                     Controlled drugs
# 706                     Controlled drugs
# 707                     Controlled drugs
# 708                    Offensive weapons
# 709                     Controlled drugs
#
# [2257 rows x 16 columns]

# %%
params4 = params = {"lat" : 51.5072,
          "lng" : -0.1276,
          "date" : "2021-05"}

# %%
mayrequest = requests.get(base_url, params=params4).json()

# %%
london_may_df = pd.DataFrame.from_dict(mayrequest)
london_may_df
# Out:
#     age_range                       outcome  involved_person  \
# 0        None  A no further action disposal             True
# 1       18-24  A no further action disposal             True
# 2       18-24  A no further action disposal             True
# 3       10-17  A no further action disposal             True
# 4        None  A no further action disposal             True
# ..        ...                           ...              ...
# 805     25-34  A no further action disposal             True
# 806     25-34  A no further action disposal             True
# 807     18-24          Community resolution             True
# 808   over 34          Community resolution             True
# 809     25-34  A no further action disposal             True
#
#                                 self_defined_ethnicity  gender  \
# 0                      Other ethnic group - Not stated    Male
# 1                      Other ethnic group - Not stated    Male
# 2          Other ethnic group - Any other ethnic group    Male
# 3          Other ethnic group - Any other ethnic group    Male
# 4    Black/African/Caribbean/Black British - Caribbean    Male
# ..                                                 ...     ...
# 805  Black/African/Caribbean/Black British - Any ot...    Male
# 806                 White - Any other White background    Male
# 807  Black/African/Caribbean/Black British - Any ot...    Male
# 808  White - English/Welsh/Scottish/Northern Irish/...    Male
# 809                    Other ethnic group - Not stated  Female
#
#                                            legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1    Police and Criminal Evidence Act 1984 (section 1)
# 2                Misuse of Drugs Act 1971 (section 23)
# 3    Police and Criminal Evidence Act 1984 (section 1)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 805  Police and Criminal Evidence Act 1984 (section 1)
# 806  Police and Criminal Evidence Act 1984 (section 1)
# 807              Misuse of Drugs Act 1971 (section 23)
# 808  Police and Criminal Evidence Act 1984 (section 1)
# 809  Police and Criminal Evidence Act 1984 (section 1)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                 True  2021-05-01T19:05:00+00:00
# 1                                False  2021-05-01T20:35:00+00:00
# 2                                 True  2021-05-01T17:35:00+00:00
# 3                                False  2021-05-01T18:45:00+00:00
# 4                                False  2021-05-01T18:25:00+00:00
# ..                                 ...                        ...
# 805                               None  2021-05-30T03:10:00+00:00
# 806                               None  2021-05-12T14:11:00+00:00
# 807                               None  2021-05-07T18:34:00+00:00
# 808                               None  2021-05-03T07:16:00+00:00
# 809                               None  2021-05-13T11:04:00+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 805                                None
# 806                                None
# 807                                None
# 808                                None
# 809                                None
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1    {'id': 'bu-no-further-action', 'name': 'A no f...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 805  {'id': 'bu-no-further-action', 'name': 'A no f...
# 806  {'id': 'bu-no-further-action', 'name': 'A no f...
# 807  {'id': 'bu-community-resolution', 'name': 'Com...
# 808  {'id': 'bu-community-resolution', 'name': 'Com...
# 809  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                               location operation  \
# 0    {'latitude': '51.503381', 'street': {'id': 149...      None
# 1    {'latitude': '51.515685', 'street': {'id': 148...      None
# 2    {'latitude': '51.515685', 'street': {'id': 148...      None
# 3    {'latitude': '51.515685', 'street': {'id': 148...      None
# 4    {'latitude': '51.515685', 'street': {'id': 148...      None
# ..                                                 ...       ...
# 805  {'latitude': '51.507613', 'street': {'id': 956...     False
# 806  {'latitude': '51.505904', 'street': {'id': 956...     False
# 807  {'latitude': '51.511694', 'street': {'id': 956...     False
# 808  {'latitude': '51.511595', 'street': {'id': 956...     False
# 809  {'latitude': '51.511238', 'street': {'id': 956...     False
#
#     officer_defined_ethnicity                       type operation_name  \
# 0                       White              Person search           None
# 1                       Black              Person search           None
# 2                       White              Person search           None
# 3                       White              Person search           None
# 4                       Black              Person search           None
# ..                        ...                        ...            ...
# 805                     Black              Person search           None
# 806                     White              Person search           None
# 807                     Black  Person and Vehicle search           None
# 808                     White              Person search           None
# 809                     White              Person search           None
#
#                         object_of_search
# 0                           Stolen goods
# 1    Anything to threaten or harm anyone
# 2                       Controlled drugs
# 3                      Offensive weapons
# 4    Anything to threaten or harm anyone
# ..                                   ...
# 805                         Stolen goods
# 806                         Stolen goods
# 807                     Controlled drugs
# 808                         Stolen goods
# 809                         Stolen goods
#
# [810 rows x 16 columns]

# %%
jan_may = jan_apr.append(london_may_df)
jan_may
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 805     25-34     A no further action disposal             True
# 806     25-34     A no further action disposal             True
# 807     18-24             Community resolution             True
# 808   over 34             Community resolution             True
# 809     25-34     A no further action disposal             True
#
#                                 self_defined_ethnicity  gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...    Male
# 1                      Asian/Asian British - Pakistani    Male
# 2    White - English/Welsh/Scottish/Northern Irish/...    Male
# 3    White - English/Welsh/Scottish/Northern Irish/...    Male
# 4    White - English/Welsh/Scottish/Northern Irish/...    Male
# ..                                                 ...     ...
# 805  Black/African/Caribbean/Black British - Any ot...    Male
# 806                 White - Any other White background    Male
# 807  Black/African/Caribbean/Black British - Any ot...    Male
# 808  White - English/Welsh/Scottish/Northern Irish/...    Male
# 809                    Other ethnic group - Not stated  Female
#
#                                            legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1                Misuse of Drugs Act 1971 (section 23)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3                Misuse of Drugs Act 1971 (section 23)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 805  Police and Criminal Evidence Act 1984 (section 1)
# 806  Police and Criminal Evidence Act 1984 (section 1)
# 807              Misuse of Drugs Act 1971 (section 23)
# 808  Police and Criminal Evidence Act 1984 (section 1)
# 809  Police and Criminal Evidence Act 1984 (section 1)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                 True  2021-01-03T14:56:00+00:00
# 1                                 True  2021-01-03T21:14:00+00:00
# 2                                False  2021-01-05T14:33:00+00:00
# 3                                False  2021-01-07T16:18:00+00:00
# 4                                False  2021-01-07T19:22:00+00:00
# ..                                 ...                        ...
# 805                               None  2021-05-30T03:10:00+00:00
# 806                               None  2021-05-12T14:11:00+00:00
# 807                               None  2021-05-07T18:34:00+00:00
# 808                               None  2021-05-03T07:16:00+00:00
# 809                               None  2021-05-13T11:04:00+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 805                                None
# 806                                None
# 807                                None
# 808                                None
# 809                                None
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1    {'id': 'bu-caution', 'name': 'Caution (simple ...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 805  {'id': 'bu-no-further-action', 'name': 'A no f...
# 806  {'id': 'bu-no-further-action', 'name': 'A no f...
# 807  {'id': 'bu-community-resolution', 'name': 'Com...
# 808  {'id': 'bu-community-resolution', 'name': 'Com...
# 809  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                               location operation  \
# 0    {'latitude': '52.477800', 'street': {'id': 148...      None
# 1    {'latitude': '52.488400', 'street': {'id': 148...      None
# 2    {'latitude': '52.481994', 'street': {'id': 148...      None
# 3    {'latitude': '52.477800', 'street': {'id': 148...      None
# 4    {'latitude': '52.478321', 'street': {'id': 149...      None
# ..                                                 ...       ...
# 805  {'latitude': '51.507613', 'street': {'id': 956...     False
# 806  {'latitude': '51.505904', 'street': {'id': 956...     False
# 807  {'latitude': '51.511694', 'street': {'id': 956...     False
# 808  {'latitude': '51.511595', 'street': {'id': 956...     False
# 809  {'latitude': '51.511238', 'street': {'id': 956...     False
#
#     officer_defined_ethnicity                       type operation_name  \
# 0                        None              Person search           None
# 1                       Asian              Person search           None
# 2                       White              Person search           None
# 3                       White              Person search           None
# 4                       White              Person search           None
# ..                        ...                        ...            ...
# 805                     Black              Person search           None
# 806                     White              Person search           None
# 807                     Black  Person and Vehicle search           None
# 808                     White              Person search           None
# 809                     White              Person search           None
#
#                         object_of_search
# 0     Evidence of offences under the Act
# 1                       Controlled drugs
# 2                           Stolen goods
# 3                       Controlled drugs
# 4    Anything to threaten or harm anyone
# ..                                   ...
# 805                         Stolen goods
# 806                         Stolen goods
# 807                     Controlled drugs
# 808                         Stolen goods
# 809                         Stolen goods
#
# [3067 rows x 16 columns]

# %%
age_range = jan_may["age_range"]
age_range.groupby(age_range).count()
# Out:
# age_range
# 10-17      394
# 18-24      992
# 25-34      711
# over 34    488
# Name: age_range, dtype: int64

# %%
outcome = jan_may["outcome"]
outcome.groupby(outcome).count()
# Out:
# outcome
#                                      14
# A no further action disposal       2222
# Arrest                              311
# Caution (simple or conditional)       3
# Community resolution                356
# Khat or Cannabis warning              4
# Penalty Notice for Disorder         119
# Summons / charged by post            38
# Name: outcome, dtype: int64

# %%
self_defined_ethnicity = jan_may["self_defined_ethnicity"]
self_defined_ethnicity.groupby(self_defined_ethnicity).count()
# Out:
# self_defined_ethnicity
# Asian/Asian British - Any other Asian background                                        133
# Asian/Asian British - Bangladeshi                                                        46
# Asian/Asian British - Chinese                                                            13
# Asian/Asian British - Indian                                                             61
# Asian/Asian British - Pakistani                                                          62
# Black/African/Caribbean/Black British - African                                         186
# Black/African/Caribbean/Black British - Any other Black/African/Caribbean background    213
# Black/African/Caribbean/Black British - Caribbean                                        92
# Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background                79
# Mixed/Multiple ethnic groups - White and Asian                                           10
# Mixed/Multiple ethnic groups - White and Black African                                   10
# Mixed/Multiple ethnic groups - White and Black Caribbean                                 34
# Other ethnic group - Any other ethnic group                                             159
# Other ethnic group - Not stated                                                         862
# White - Any other White background                                                      402
# White - English/Welsh/Scottish/Northern Irish/British                                   650
# White - Irish                                                                            30
# Name: self_defined_ethnicity, dtype: int64

# %%
officer_defined_ethnicity = jan_may["officer_defined_ethnicity"]
officer_defined_ethnicity.groupby(officer_defined_ethnicity).count()
# Out:
# officer_defined_ethnicity
# Asian     413
# Black     764
# Other     284
# White    1436
# Name: officer_defined_ethnicity, dtype: int64

# %%
gender = jan_may["gender"]
gender.groupby(gender).count()
# Out:
# gender
# Female     308
# Male      2602
# Other        5
# Name: gender, dtype: int64
