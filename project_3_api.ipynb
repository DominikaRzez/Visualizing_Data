# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import seaborn as sns
import scipy.stats as st
import os
import gmaps
import json

# %%
base_url = "https://data.police.uk/api/stops-street?"

# %% [markdown]
# poly	The lat/lng pairs which define the boundary of the custom area
#
# date	Optional. (YYYY-MM) Limit results to a specific month.
#
# The latest month will be shown by default
#
# The poly parameter is formatted in lat/lng pairs, separated by colons:
#
# [lat],[lng]:[lat],[lng]:[lat],[lng]

# %% [markdown]
# Specific point Example
#
# https://data.police.uk/api/stops-street?lat=52.629729&lng=-1.131592&date=2018-06

# %%
params = {"lat" : 52.4862,
          "lng" : -1.8904,
          "date" : "2021-01"
         }

# %%
january = requests.get(base_url, params=params).json()

# %%
january
# Out:
# [{'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-01-03T14:56:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.477800',
#    'street': {'id': 1488803, 'name': 'Grand Central (Tram Stop)'},
#    'longitude': '-1.898950'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Evidence of offences under the Act'},
#  {'age_range': '18-24',
#   'outcome': 'Caution (simple or conditional)',
#   'involved_person': True,
# ...

# %%
jan = pd.DataFrame.from_dict(january)

# %%
jan
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 142     10-17                                              True
# 143     18-24     A no further action disposal             True
# 144     18-24     A no further action disposal             True
# 145      None     A no further action disposal             True
# 146     25-34     A no further action disposal             True
#
#                                 self_defined_ethnicity gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...   Male
# 1                      Asian/Asian British - Pakistani   Male
# ...

# %%
params1 = params = {"lat" : 52.4862,
          "lng" : -1.8904,
          "date" : "2021-02"
         }

# %%
february = requests.get(base_url, params=params1).json()

# %%
feb = pd.DataFrame.from_dict(february)

# %%
feb
# Out:
#     age_range                       outcome  involved_person  \
# 0       10-17                        Arrest             True
# 1       10-17  A no further action disposal             True
# 2        None                        Arrest             True
# 3     over 34  A no further action disposal             True
# 4     over 34                        Arrest             True
# ..        ...                           ...              ...
# 205     18-24  A no further action disposal             True
# 206     18-24  A no further action disposal             True
# 207     18-24  A no further action disposal             True
# 208     10-17  A no further action disposal             True
# 209   over 34  A no further action disposal             True
#
#                                 self_defined_ethnicity  gender  \
# 0    Black/African/Caribbean/Black British - Any ot...    Male
# 1    Black/African/Caribbean/Black British - Caribbean    Male
# ...

# %%
params2 = params = {"lat" : 52.4862,
          "lng" : -1.8904,
          "date" : "2021-03"
         }

# %%
march = requests.get(base_url, params=params2).json()

# %%
mar = pd.DataFrame.from_dict(march)

# %%
mar
# Out:
#     age_range                       outcome  involved_person  \
# 0       18-24  A no further action disposal             True
# 1       18-24  A no further action disposal             True
# 2       25-34  A no further action disposal             True
# 3       18-24  A no further action disposal             True
# 4       18-24  A no further action disposal             True
# ..        ...                           ...              ...
# 333     25-34                        Arrest             True
# 334     18-24  A no further action disposal             True
# 335     18-24  A no further action disposal             True
# 336   over 34  A no further action disposal             True
# 337   over 34  A no further action disposal             True
#
#                                 self_defined_ethnicity gender  \
# 0    Mixed/Multiple ethnic groups - White and Black...   None
# 1    Black/African/Caribbean/Black British - Caribbean   None
# ...

# %%
params3 = params = {"lat" : 52.4862,
          "lng" : -1.8904,
          "date" : "2021-04"
         }

# %%
april = requests.get(base_url, params=params3).json()

# %%
apr = pd.DataFrame.from_dict(april)

# %%
apr
# Out:
#    age_range                       outcome  involved_person  \
# 0      25-34                        Arrest             True
# 1      18-24                        Arrest             True
# 2      10-17  A no further action disposal             True
# 3      25-34  A no further action disposal             True
# 4      18-24  A no further action disposal             True
# 5      18-24                        Arrest             True
# 6    over 34  A no further action disposal             True
# 7      18-24  A no further action disposal             True
# 8      18-24                        Arrest             True
# 9      18-24  A no further action disposal             True
# 10     25-34  A no further action disposal             True
# 11   over 34  A no further action disposal             True
# 12     25-34  A no further action disposal             True
# 13     18-24  A no further action disposal             True
# 14     10-17  A no further action disposal             True
# ...

# %%
jan_feb = jan.append(feb)

# %%
jan_feb
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 205     18-24     A no further action disposal             True
# 206     18-24     A no further action disposal             True
# 207     18-24     A no further action disposal             True
# 208     10-17     A no further action disposal             True
# 209   over 34     A no further action disposal             True
#
#                                 self_defined_ethnicity  gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...    Male
# 1                      Asian/Asian British - Pakistani    Male
# ...

# %%
jan_mar = jan_feb.append(mar)

# %%
jan_mar
# Out:
#     age_range                          outcome  involved_person  \
# 0     over 34     A no further action disposal             True
# 1       18-24  Caution (simple or conditional)             True
# 2     over 34     A no further action disposal             True
# 3       10-17     A no further action disposal             True
# 4     over 34     A no further action disposal             True
# ..        ...                              ...              ...
# 333     25-34                           Arrest             True
# 334     18-24     A no further action disposal             True
# 335     18-24     A no further action disposal             True
# 336   over 34     A no further action disposal             True
# 337   over 34     A no further action disposal             True
#
#                                 self_defined_ethnicity gender  \
# 0    White - English/Welsh/Scottish/Northern Irish/...   Male
# 1                      Asian/Asian British - Pakistani   Male
# ...

# %%
jan_apr = jan_mar.append(apr)

# %%
jan_apr.head(50)
# Out:
#    age_range                          outcome  involved_person  \
# 0    over 34     A no further action disposal             True
# 1      18-24  Caution (simple or conditional)             True
# 2    over 34     A no further action disposal             True
# 3      10-17     A no further action disposal             True
# 4    over 34     A no further action disposal             True
# 5      18-24     A no further action disposal             True
# 6      18-24     A no further action disposal             True
# 7      18-24     A no further action disposal             True
# 8      10-17     A no further action disposal             True
# 9      10-17     A no further action disposal             True
# 10     18-24     A no further action disposal             True
# 11     25-34     A no further action disposal             True
# 12   over 34     A no further action disposal             True
# 13     18-24     A no further action disposal             True
# ...

# %%
params4 = params = {"lat" : 52.4862,
          "lng" : -1.8904,
          "date" : "2021-05"
         }

# %%
mayrequest = requests.get(base_url, params=params4).json()

# %%
may = pd.DataFrame.from_dict(mayrequest)

# %%
jan_may = jan_apr.append(may)

# %%
jan_may.head(50)
# Out:
#    age_range                          outcome  involved_person  \
# 0    over 34     A no further action disposal             True
# 1      18-24  Caution (simple or conditional)             True
# 2    over 34     A no further action disposal             True
# 3      10-17     A no further action disposal             True
# 4    over 34     A no further action disposal             True
# 5      18-24     A no further action disposal             True
# 6      18-24     A no further action disposal             True
# 7      18-24     A no further action disposal             True
# 8      10-17     A no further action disposal             True
# 9      10-17     A no further action disposal             True
# 10     18-24     A no further action disposal             True
# 11     25-34     A no further action disposal             True
# 12   over 34     A no further action disposal             True
# 13     18-24     A no further action disposal             True
# ...

# %%
age_range = jan_may["age_range"]
age_range.groupby(age_range).count()
# Out:
# age_range
# 10-17      116
# 18-24      208
# 25-34      114
# over 34     98
# Name: age_range, dtype: int64

# %%
outcome = jan_may["outcome"]
outcome.groupby(outcome).count()
# Out:
# outcome
#                                     45
# A no further action disposal       519
# Arrest                              94
# Caution (simple or conditional)      3
# Community resolution                41
# Khat or Cannabis warning            15
# Penalty Notice for Disorder         11
# Summons / charged by post            4
# Name: outcome, dtype: int64

# %%
self_defined_ethnicity = jan_may["self_defined_ethnicity"]
self_defined_ethnicity.groupby(self_defined_ethnicity).count()
# Out:
# self_defined_ethnicity
# Asian/Asian British - Any other Asian background                                         32
# Asian/Asian British - Bangladeshi                                                        24
# Asian/Asian British - Chinese                                                             3
# Asian/Asian British - Indian                                                             29
# Asian/Asian British - Pakistani                                                          95
# Black/African/Caribbean/Black British - African                                          66
# Black/African/Caribbean/Black British - Any other Black/African/Caribbean background     32
# Black/African/Caribbean/Black British - Caribbean                                        79
# Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background                18
# Mixed/Multiple ethnic groups - White and Asian                                            6
# ...

# %%
officer_defined_ethnicity = jan_may["officer_defined_ethnicity"]
officer_defined_ethnicity.groupby(officer_defined_ethnicity).count()
# Out:
# officer_defined_ethnicity
# Asian    152
# Black     23
# Other     24
# White     38
# Name: officer_defined_ethnicity, dtype: int64

# %%
object_of_search = jan_may["object_of_search"]
object_of_search.groupby(object_of_search).count()
# Out:
# object_of_search
# Anything to threaten or harm anyone     15
# Article for use in theft                55
# Articles for use in criminal damage      4
# Controlled drugs                       425
# Evidence of offences under the Act       4
# Firearms                                 7
# Offensive weapons                      158
# Stolen goods                            64
# Name: object_of_search, dtype: int64

# %%
gender = jan_may["gender"]
gender.groupby(gender).count()
# Out:
# gender
# Female     8
# Male      75
# Name: gender, dtype: int64
