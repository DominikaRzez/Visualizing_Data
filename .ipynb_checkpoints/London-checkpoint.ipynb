# %%
 # Dependencies
import requests
import json
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
import seaborn as sns
import scipy.stats as st
import os
import gmaps

# %%
# URL for GET requests to retrieve data

base_url = "https://data.police.uk/api/stops-street?"
location = "lat=51.5072&lng=-0.1276&date="
dates = ["2021-01","2021-02","2021-03","2021-04","2021-05"]

jan_may = []
for date in dates:
    query_url = base_url + location + date
    response = requests.get(query_url).json()
    jan_may.append(response)

# %%
London_data = pd.DataFrame.from_dict(jan_may[0])
London_data = London_data.append(pd.DataFrame.from_dict(jan_may[1]))
London_data = London_data.append(pd.DataFrame.from_dict(jan_may[2]))
London_data = London_data.append(pd.DataFrame.from_dict(jan_may[3]))
London_data = London_data.append(pd.DataFrame.from_dict(jan_may[4]))
London_data
# Out:
#     age_range                       outcome  involved_person  \
# 0       18-24  A no further action disposal             True
# 1       25-34  A no further action disposal             True
# 2       10-17  A no further action disposal             True
# 3       10-17  A no further action disposal             True
# 4     over 34  A no further action disposal             True
# ..        ...                           ...              ...
# 805     25-34  A no further action disposal             True
# 806     25-34  A no further action disposal             True
# 807     18-24          Community resolution             True
# 808   over 34          Community resolution             True
# 809     25-34  A no further action disposal             True
#
#                                 self_defined_ethnicity  gender  \
# 0                      Other ethnic group - Not stated    Male
# 1                      Other ethnic group - Not stated    Male
# 2    White - English/Welsh/Scottish/Northern Irish/...    Male
# 3    White - English/Welsh/Scottish/Northern Irish/...    Male
# 4      Black/African/Caribbean/Black British - African    Male
# ..                                                 ...     ...
# 805  Black/African/Caribbean/Black British - Any ot...    Male
# 806                 White - Any other White background    Male
# 807  Black/African/Caribbean/Black British - Any ot...    Male
# 808  White - English/Welsh/Scottish/Northern Irish/...    Male
# 809                    Other ethnic group - Not stated  Female
#
#                                            legislation  \
# 0                Misuse of Drugs Act 1971 (section 23)
# 1    Police and Criminal Evidence Act 1984 (section 1)
# 2                Misuse of Drugs Act 1971 (section 23)
# 3                Misuse of Drugs Act 1971 (section 23)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 805  Police and Criminal Evidence Act 1984 (section 1)
# 806  Police and Criminal Evidence Act 1984 (section 1)
# 807              Misuse of Drugs Act 1971 (section 23)
# 808  Police and Criminal Evidence Act 1984 (section 1)
# 809  Police and Criminal Evidence Act 1984 (section 1)
#
#     outcome_linked_to_object_of_search                   datetime  \
# 0                                 True  2021-01-01T04:07:00+00:00
# 1                                False  2021-01-03T19:50:00+00:00
# 2                                 True  2021-01-04T17:17:00+00:00
# 3                                False  2021-01-04T16:20:00+00:00
# 4                                False  2021-01-04T21:00:00+00:00
# ..                                 ...                        ...
# 805                               None  2021-05-30T03:10:00+00:00
# 806                               None  2021-05-12T14:11:00+00:00
# 807                               None  2021-05-07T18:34:00+00:00
# 808                               None  2021-05-03T07:16:00+00:00
# 809                               None  2021-05-13T11:04:00+00:00
#
#     removal_of_more_than_outer_clothing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 805                                None
# 806                                None
# 807                                None
# 808                                None
# 809                                None
#
#                                         outcome_object  \
# 0    {'id': 'bu-no-further-action', 'name': 'A no f...
# 1    {'id': 'bu-no-further-action', 'name': 'A no f...
# 2    {'id': 'bu-no-further-action', 'name': 'A no f...
# 3    {'id': 'bu-no-further-action', 'name': 'A no f...
# 4    {'id': 'bu-no-further-action', 'name': 'A no f...
# ..                                                 ...
# 805  {'id': 'bu-no-further-action', 'name': 'A no f...
# 806  {'id': 'bu-no-further-action', 'name': 'A no f...
# 807  {'id': 'bu-community-resolution', 'name': 'Com...
# 808  {'id': 'bu-community-resolution', 'name': 'Com...
# 809  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                               location operation  \
# 0    {'latitude': '51.510100', 'street': {'id': 148...      None
# 1    {'latitude': '51.503381', 'street': {'id': 149...      None
# 2    {'latitude': '51.503381', 'street': {'id': 149...      None
# 3    {'latitude': '51.503381', 'street': {'id': 149...      None
# 4    {'latitude': '51.503381', 'street': {'id': 149...      None
# ..                                                 ...       ...
# 805  {'latitude': '51.507613', 'street': {'id': 956...     False
# 806  {'latitude': '51.505904', 'street': {'id': 956...     False
# 807  {'latitude': '51.511694', 'street': {'id': 956...     False
# 808  {'latitude': '51.511595', 'street': {'id': 956...     False
# 809  {'latitude': '51.511238', 'street': {'id': 956...     False
#
#     officer_defined_ethnicity                       type operation_name  \
# 0                       Black              Person search           None
# 1                       White              Person search           None
# 2                       White              Person search           None
# 3                       White              Person search           None
# 4                       Black              Person search           None
# ..                        ...                        ...            ...
# 805                     Black              Person search           None
# 806                     White              Person search           None
# 807                     Black  Person and Vehicle search           None
# 808                     White              Person search           None
# 809                     White              Person search           None
#
#       object_of_search
# 0     Controlled drugs
# 1    Offensive weapons
# 2     Controlled drugs
# 3     Controlled drugs
# 4         Stolen goods
# ..                 ...
# 805       Stolen goods
# 806       Stolen goods
# 807   Controlled drugs
# 808       Stolen goods
# 809       Stolen goods
#
# [3451 rows x 16 columns]

# %%
London_info = London_data[["age_range", "self_defined_ethnicity", "gender", "officer_defined_ethnicity", "object_of_search", "location"]]
London_info
# Out:
#     age_range                             self_defined_ethnicity  gender  \
# 0       18-24                    Other ethnic group - Not stated    Male
# 1       25-34                    Other ethnic group - Not stated    Male
# 2       10-17  White - English/Welsh/Scottish/Northern Irish/...    Male
# 3       10-17  White - English/Welsh/Scottish/Northern Irish/...    Male
# 4     over 34    Black/African/Caribbean/Black British - African    Male
# ..        ...                                                ...     ...
# 805     25-34  Black/African/Caribbean/Black British - Any ot...    Male
# 806     25-34                 White - Any other White background    Male
# 807     18-24  Black/African/Caribbean/Black British - Any ot...    Male
# 808   over 34  White - English/Welsh/Scottish/Northern Irish/...    Male
# 809     25-34                    Other ethnic group - Not stated  Female
#
#     officer_defined_ethnicity   object_of_search  \
# 0                       Black   Controlled drugs
# 1                       White  Offensive weapons
# 2                       White   Controlled drugs
# 3                       White   Controlled drugs
# 4                       Black       Stolen goods
# ..                        ...                ...
# 805                     Black       Stolen goods
# 806                     White       Stolen goods
# 807                     Black   Controlled drugs
# 808                     White       Stolen goods
# 809                     White       Stolen goods
#
#                                               location
# 0    {'latitude': '51.510100', 'street': {'id': 148...
# 1    {'latitude': '51.503381', 'street': {'id': 149...
# 2    {'latitude': '51.503381', 'street': {'id': 149...
# 3    {'latitude': '51.503381', 'street': {'id': 149...
# 4    {'latitude': '51.503381', 'street': {'id': 149...
# ..                                                 ...
# 805  {'latitude': '51.507613', 'street': {'id': 956...
# 806  {'latitude': '51.505904', 'street': {'id': 956...
# 807  {'latitude': '51.511694', 'street': {'id': 956...
# 808  {'latitude': '51.511595', 'street': {'id': 956...
# 809  {'latitude': '51.511238', 'street': {'id': 956...
#
# [3451 rows x 6 columns]

# %%
London_info.to_csv("Liverpool_data.csv", index = False)

# %%
age_range = London_info["age_range"]
age_range.groupby(age_range).count()
# Out:
# age_range
# 10-17       442
# 18-24      1119
# 25-34       802
# over 34     580
# Name: age_range, dtype: int64

# %%
outcome = London_info["object_of_search"]
outcome.groupby(outcome).count()
# Out:
# object_of_search
# Anything to threaten or harm anyone      58
# Article for use in theft                  9
# Articles for use in criminal damage      51
# Controlled drugs                       2070
# Evidence of offences under the Act      119
# Firearms                                  3
# Fireworks                                 6
# Offensive weapons                       359
# Stolen goods                            766
# Name: object_of_search, dtype: int64

# %%
self_defined_ethnicity = London_info["self_defined_ethnicity"]
self_defined_ethnicity.groupby(self_defined_ethnicity).count()
# Out:
# self_defined_ethnicity
# Asian/Asian British - Any other Asian background                                         125
# Asian/Asian British - Bangladeshi                                                         41
# Asian/Asian British - Chinese                                                             11
# Asian/Asian British - Indian                                                              51
# Asian/Asian British - Pakistani                                                           41
# Black/African/Caribbean/Black British - African                                          207
# Black/African/Caribbean/Black British - Any other Black/African/Caribbean background     260
# Black/African/Caribbean/Black British - Caribbean                                         88
# Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background                 80
# Mixed/Multiple ethnic groups - White and Asian                                             9
# Mixed/Multiple ethnic groups - White and Black African                                    11
# Mixed/Multiple ethnic groups - White and Black Caribbean                                  31
# Other ethnic group - Any other ethnic group                                              165
# Other ethnic group - Not stated                                                         1061
# White - Any other White background                                                       479
# White - English/Welsh/Scottish/Northern Irish/British                                    737
# White - Irish                                                                             33
# Name: self_defined_ethnicity, dtype: int64

# %%
officer_defined_ethnicity = London_info["officer_defined_ethnicity"]
officer_defined_ethnicity.groupby(officer_defined_ethnicity).count()
# Out:
# officer_defined_ethnicity
# Asian     384
# Black     930
# Other     305
# White    1752
# Name: officer_defined_ethnicity, dtype: int64

# %%
gender = London_info["gender"]
gender.groupby(gender).count()
# Out:
# gender
# Female     340
# Male      3069
# Other        6
# Name: gender, dtype: int64

# %%
ethnicity = London_info["officer_defined_ethnicity"]
ethnicity.groupby(ethnicity).count()
# Out:
# officer_defined_ethnicity
# Asian     384
# Black     930
# Other     305
# White    1752
# Name: officer_defined_ethnicity, dtype: int64
